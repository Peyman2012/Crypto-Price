# %%
pip install pycoingecko #import library
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycoingecko import CoinGeckoAPI

# %%
cg = CoinGeckoAPI()

# %%
data = cg.get_price(ids='bitcoin,ethereum',vs_currencies = "usd,eur") #Get dollar and euro bitcoin prices

# %%
data
# Out:
# {'bitcoin': {'usd': 24500, 'eur': 22862},
#  'ethereum': {'usd': 1690.33, 'eur': 1577.31}}

# %%
coins = cg.get_coins_list()

# %%
coins
# Out:
# [{'id': '01coin', 'symbol': 'zoc', 'name': '01coin'},
#  {'id': '0chain', 'symbol': 'zcn', 'name': 'Zus'},
#  {'id': '0x', 'symbol': 'zrx', 'name': '0x'},
#  {'id': '0x0-ai-ai-smart-contract',
#   'symbol': '0x0',
#   'name': '0x0.ai: AI Smart Contract'},
#  {'id': '0xcert', 'symbol': 'zxc', 'name': '0xcert'},
#  {'id': '0xdao', 'symbol': 'oxd', 'name': '0xDAO'},
#  {'id': '0xdao-v2', 'symbol': 'oxd v2', 'name': '0xDAO V2'},
#  {'id': '0xmonero', 'symbol': '0xmr', 'name': '0xMonero'},
#  {'id': '0xpad', 'symbol': '0xpad', 'name': '0xPAD'},
#  {'id': '0xtrade', 'symbol': '0xt', 'name': '0xTrade'},
#  {'id': '0xwallet-token', 'symbol': '0xw', 'name': '0xWallet Token'},
#  {'id': '11957-olga',
#   'symbol': 'realt-s-11957-olga-st-detroit-mi',
#   'name': 'RealT - 11957 Olga St, Detroit, MI 48213'},
#  {'id': '12405-santa-rosa',
#   'symbol': 'realt-s-12405-santa-rosa-dr-detroit-mi',
#   'name': 'RealT - 12405 Santa Rosa Dr, Detroit, MI 48204'},
# ...

# %%
data_market = cg.get_coins_markets(vs_currency = "usd")

# %%
data_market
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 24500,
#   'market_cap': 472769734248,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 514552979873,
#   'total_volume': 47512023789,
#   'high_24h': 24949,
#   'low_24h': 23767,
#   'price_change_24h': 733.68,
#   'price_change_percentage_24h': 3.08702,
#   'market_cap_change_24h': 14874310719,
#   'market_cap_change_percentage_24h': 3.24841,
#   'circulating_supply': 19294737.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -64.51212,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 36034.6176,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-02-18T11:21:32.229Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      bitcoin  ethereum
# usd    24500   1690.33
# eur    22862   1577.31

# %%
df_coins = pd.DataFrame(coins,columns=["symbol"])

# %%
df_coins
# Out:
#       symbol
# 0        zoc
# 1        zcn
# 2        vix
# 3        zrx
# 4        0x0
# ...      ...
# 12279    zyb
# 12280    zyn
# 12281   zyro
# 12282    zyr
# 12283    zyx
#
# [12284 rows x 1 columns]

# %%
df_market = pd.DataFrame(data_market,columns=["id","current_price"])
df_market
# Out:
#                 id  current_price
# 0          bitcoin   24500.000000
# 1         ethereum    1690.580000
# 2           tether       1.000000
# 3      binancecoin     314.680000
# 4         usd-coin       0.999890
# ..             ...            ...
# 95  singularitynet       0.428289
# 96  convex-finance       6.660000
# 97           radix       0.049090
# 98  compound-ether      33.960000
# 99       enjincoin       0.480859
#
# [100 rows x 2 columns]

# %%
df_market = pd.DataFrame(data_market,columns=["id","current_price"])

# %%
df_market.set_index("id",inplace=True)

# %%
df_market
# Out:
#                 current_price
# id
# bitcoin          24500.000000
# ethereum          1690.580000
# tether               1.000000
# binancecoin        314.680000
# usd-coin             0.999890
# ...                       ...
# singularitynet       0.428289
# convex-finance       6.660000
# radix                0.049090
# compound-ether      33.960000
# enjincoin            0.480859
#
# [100 rows x 1 columns]

# %%
df_market.loc["bitcoin"]
# Out:
# current_price    24500.0
# Name: bitcoin, dtype: float64

# %%
df_market.loc["bitcoin"][0] #price bitcoin
# Out:
# 24500.0

# %%
df_market.shape
# Out:
# (100, 1)
